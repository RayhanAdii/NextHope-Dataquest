# %%
import pandas as pd

# %%
df_train = pd.read_csv('./dataset/train_ts_feature_added_2.csv')
df_train['datetime_iso'] = pd.to_datetime(df_train['datetime_iso'])

df_test = pd.read_csv('./dataset/test_ts_feature_added_2.csv')
df_test['datetime_iso'] = pd.to_datetime(df_test['datetime_iso'])
df_test_date = df_test['datetime_iso']

# %%
df_train.head()
# Out:
#                datetime_iso   temp  d_point  feels  min_temp  max_temp  \
# 0 1985-01-01 00:00:00+00:00  24.95    23.56  25.90     24.59     25.30
# 1 1985-01-01 01:00:00+00:00  25.62    23.48  26.54     25.28     25.96
# 2 1985-01-01 02:00:00+00:00  28.09    24.10  32.17     27.74     28.43
# 3 1985-01-01 03:00:00+00:00  26.20    23.83  33.33     28.39     29.53
# 4 1985-01-01 04:00:00+00:00  29.68    23.62  34.27     28.86     30.53
#
#     prssr   hum  wind_spd  wind_deg  rain_1h  clouds  day_of_the_week  month  \
# 0  1011.0  92.0      1.55     326.0     0.00   100.0                1      1
# 1  1011.0  88.0      1.20     314.0     0.11    98.0                1      1
# 2  1011.0  79.0      0.99     280.0     0.10   100.0                1      1
# 3  1011.0  74.0      1.04     268.0     0.13   100.0                1      1
# 4  1009.0  70.0      1.50     248.0     0.33   100.0                1      1
#
# ...

# %% [markdown]
# ## Modelling using Pycaret:Catboost

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289272 entries, 0 to 289271
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   datetime_iso               289272 non-null  datetime64[ns, UTC]
#  1   temp                       289272 non-null  float64
#  2   d_point                    289272 non-null  float64
#  3   feels                      289272 non-null  float64
#  4   min_temp                   289272 non-null  float64
#  5   max_temp                   289272 non-null  float64
#  6   prssr                      289272 non-null  float64
#  7   hum                        289272 non-null  float64
#  8   wind_spd                   289272 non-null  float64
#  9   wind_deg                   289272 non-null  float64
#  10  rain_1h                    289272 non-null  float64
#  11  clouds                     289272 non-null  float64
# ...

# %%
df_train = df_train.drop(['datetime_iso','lag_rain_1h_6_years_date'],axis = 1)
df_test = df_test.drop(['datetime_iso','lag_rain_1h_6_years_date'],axis = 1)

# %%
from pycaret.regression import *
s = setup(df_train, target = 'rain_1h', session_id = 41)
# Out:
# <style type="text/css">
# #T_fff99_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fff99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fff99_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fff99_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fff99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fff99_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fff99_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_fff99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fff99_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fff99_row1_col1" class="data row1 col1" >rain_1h</td>
#     </tr>
#     <tr>
#       <th id="T_fff99_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#best = compare_models()

# %%
catboost = create_model('catboost')
# Out:
# <style type="text/css">
# #T_11c66_row10_col0, #T_11c66_row10_col1, #T_11c66_row10_col2, #T_11c66_row10_col3, #T_11c66_row10_col4, #T_11c66_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_11c66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11c66_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_11c66_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_11c66_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_11c66_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_11c66_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_11c66_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
predictions = predict_model(catboost, data=df_test)
predictions.head()
# Out:
#     temp    d_point      feels   min_temp   max_temp   prssr   hum  wind_spd  \
# 0  26.59  23.660000  26.590000  26.020000  27.160000  1009.0  84.0      1.45
# 1  26.51  24.920000  26.510000  26.059999  28.040001  1009.0  91.0      1.67
# 2  28.68  25.709999  34.680000  28.030001  29.299999  1009.0  84.0      1.72
# 3  28.84  25.250000  34.509998  28.520000  29.080000  1008.0  81.0      1.49
# 4  29.75  24.620001  35.380001  29.309999  30.570000  1007.0  74.0      1.39
#
#    wind_deg  clouds  day_of_the_week  month  season  yearly_mean  \
# 0     355.0    97.0                0      1       1     0.492286
# 1     351.0    95.0                0      1       1     0.492286
# 2     345.0    90.0                0      1       1     0.492286
# 3     339.0    91.0                0      1       1     0.492286
# 4     339.0    96.0                0      1       1     0.492286
#
#    monthly_mean  weekly_mean  lag_rain_1h_6_years_value  prediction_label
# ...

# %%
submission = pd.DataFrame()
submission['datetime_iso'] = df_test_date
submission['rain_1h'] = predictions['prediction_label']
submission.head()
# Out:
#                datetime_iso   rain_1h
# 0 2018-01-01 00:00:00+00:00  0.481600
# 1 2018-01-01 01:00:00+00:00  0.341345
# 2 2018-01-01 02:00:00+00:00  1.035978
# 3 2018-01-01 03:00:00+00:00  1.423889
# 4 2018-01-01 04:00:00+00:00  0.672298

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49368 entries, 0 to 49367
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime_iso  49368 non-null  datetime64[ns, UTC]
#  1   rain_1h       49368 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1)
# memory usage: 771.5 KB

# %%
submission.to_csv('./submission/submission_6.csv', index=False)
