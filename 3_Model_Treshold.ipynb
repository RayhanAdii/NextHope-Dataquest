# %% [markdown]
# ### Kita Coba bikin model pake pycaret full auto

# %%
import pandas as pd

# %%
df_train = pd.read_csv('./dataset/train_cleaned.csv')
df_train['datetime_iso'] = pd.to_datetime(df_train['datetime_iso'])

df_test = pd.read_csv('./dataset/test_cleaned.csv')
df_test['datetime_iso'] = pd.to_datetime(df_test['datetime_iso'])

# %%
df_train.head()
# Out:
#     datetime              datetime_iso  time-zone   temp    visibility  \
# 0  283996800 1979-01-01 00:00:00+00:00      28800  24.75           NaN
# 1  284000400 1979-01-01 01:00:00+00:00      28800  24.58           NaN
# 2  284004000 1979-01-01 02:00:00+00:00      28800  26.60  unidentified
# 3  284007600 1979-01-01 03:00:00+00:00      28800  27.31           NaN
# 4  284011200 1979-01-01 04:00:00+00:00      28800  27.41           NaN
#
#    d_point  feels  min_temp  max_temp   prssr     sea_level    grnd_level  \
# 0    23.89  25.76     24.28     25.22  1012.0  undetermined           NaN
# 1    23.73  25.57     23.99     25.26  1012.0           NaN           NaN
# 2    24.06  26.60     26.10     27.39  1012.0           NaN  undetermined
# 3    24.37  30.90     26.59     28.36  1012.0           NaN  undetermined
# 4    25.05  31.54     26.58     28.31  1011.0           NaN  undetermined
#
#     hum  wind_spd  wind_deg  rain_1h      rain_3h snow_1h snow_3h  clouds
# 0  95.0      0.82     320.0     0.00            0     NaN     NaN   100.0
# 1  95.0      0.96     338.0     0.00            0       0       0   100.0
# 2  86.0      1.22     339.0     0.00  volume:zero     NaN     NaN    99.0
# 3  84.0      1.08     342.0     0.13          nol       0     NaN    94.0
# 4  87.0      0.86     336.0     0.34          nol     NaN       0   100.0

# %% [markdown]
# ## Percobaan 1: Drop datetime only

# %%
df_train = df_train.drop(['datetime','datetime_iso','time-zone'],axis = 1)
df_test = df_test.drop(['datetime','datetime_iso','time-zone'],axis = 1)

# %%
from pycaret.regression import *
s = setup(df_train, target = 'rain_1h', session_id = 123)
# Out:
# <style type="text/css">
# #T_7d489_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7d489">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d489_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7d489_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d489_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d489_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7d489_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d489_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7d489_row1_col1" class="data row1 col1" >rain_1h</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d489_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7d489_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d489_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7d489_row3_col1" class="data row3 col1" >(341880, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d489_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7d489_row4_col1" class="data row4 col1" >(341880, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d489_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7d489_row5_col1" class="data row5 col1" >(239315, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d489_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7d489_row6_col1" class="data row6 col1" >(102565, 71)</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d489_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7d489_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d489_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_7d489_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d489_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_7d489_row9_col1" class="data row9 col1" >99.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7d489_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_7d489_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7d489_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_7d489_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7d489_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_7d489_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7d489_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_7d489_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7d489_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_7d489_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7d489_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_7d489_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7d489_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_7d489_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7d489_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_7d489_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7d489_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_7d489_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7d489_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_7d489_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7d489_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_7d489_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7d489_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_7d489_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7d489_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7d489_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_7d489_row22_col1" class="data row22 col1" >3f13</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               21:26:59
# Status     . . . . . . . . . . . . . . . . . .       Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Regressor
# <style type="text/css">
# #T_f424c th {
#   text-align: left;
# }
# #T_f424c_row0_col0, #T_f424c_row0_col1, #T_f424c_row0_col2, #T_f424c_row0_col3, #T_f424c_row0_col4, #T_f424c_row0_col5, #T_f424c_row0_col6, #T_f424c_row0_col7, #T_f424c_row1_col0, #T_f424c_row1_col1, #T_f424c_row1_col2, #T_f424c_row1_col3, #T_f424c_row1_col4, #T_f424c_row1_col5, #T_f424c_row1_col6, #T_f424c_row1_col7, #T_f424c_row2_col0, #T_f424c_row2_col1, #T_f424c_row2_col2, #T_f424c_row2_col3, #T_f424c_row2_col4, #T_f424c_row2_col5, #T_f424c_row2_col6, #T_f424c_row2_col7, #T_f424c_row3_col0, #T_f424c_row3_col1, #T_f424c_row3_col2, #T_f424c_row3_col3, #T_f424c_row3_col4, #T_f424c_row3_col5, #T_f424c_row3_col6, #T_f424c_row3_col7, #T_f424c_row4_col0, #T_f424c_row4_col1, #T_f424c_row4_col2, #T_f424c_row4_col3, #T_f424c_row4_col4, #T_f424c_row4_col5, #T_f424c_row4_col6, #T_f424c_row4_col7, #T_f424c_row5_col0, #T_f424c_row5_col1, #T_f424c_row5_col2, #T_f424c_row5_col3, #T_f424c_row5_col4, #T_f424c_row5_col5, #T_f424c_row5_col6, #T_f424c_row5_col7, #T_f424c_row6_col0, #T_f424c_row6_col1, #T_f424c_row6_col2, #T_f424c_row6_col3, #T_f424c_row6_col4, #T_f424c_row6_col5, #T_f424c_row6_col6, #T_f424c_row6_col7, #T_f424c_row7_col0, #T_f424c_row7_col1, #T_f424c_row7_col2, #T_f424c_row7_col3, #T_f424c_row7_col4, #T_f424c_row7_col5, #T_f424c_row7_col6, #T_f424c_row7_col7, #T_f424c_row8_col0, #T_f424c_row8_col1, #T_f424c_row8_col2, #T_f424c_row8_col3, #T_f424c_row8_col4, #T_f424c_row8_col5, #T_f424c_row8_col6, #T_f424c_row8_col7, #T_f424c_row9_col0, #T_f424c_row9_col1, #T_f424c_row9_col2, #T_f424c_row9_col3, #T_f424c_row9_col4, #T_f424c_row9_col5, #T_f424c_row9_col6, #T_f424c_row9_col7, #T_f424c_row10_col0, #T_f424c_row10_col1, #T_f424c_row10_col2, #T_f424c_row10_col3, #T_f424c_row10_col4, #T_f424c_row10_col5, #T_f424c_row10_col6, #T_f424c_row10_col7, #T_f424c_row11_col0, #T_f424c_row11_col1, #T_f424c_row11_col2, #T_f424c_row11_col3, #T_f424c_row11_col4, #T_f424c_row11_col5, #T_f424c_row11_col6, #T_f424c_row11_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_f424c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f424c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f424c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f424c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f424c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f424c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f424c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f424c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f424c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f424c_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_f424c_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_f424c_row0_col1" class="data row0 col1" >0.5027</td>
#       <td id="T_f424c_row0_col2" class="data row0 col2" >0.8701</td>
#       <td id="T_f424c_row0_col3" class="data row0 col3" >0.9325</td>
#       <td id="T_f424c_row0_col4" class="data row0 col4" >0.0219</td>
#       <td id="T_f424c_row0_col5" class="data row0 col5" >0.3988</td>
#       <td id="T_f424c_row0_col6" class="data row0 col6" >0.9587</td>
#       <td id="T_f424c_row0_col7" class="data row0 col7" >1.3610</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_f424c_row1_col0" class="data row1 col0" >Linear Regression</td>
#       <td id="T_f424c_row1_col1" class="data row1 col1" >0.5028</td>
#       <td id="T_f424c_row1_col2" class="data row1 col2" >0.8702</td>
#       <td id="T_f424c_row1_col3" class="data row1 col3" >0.9325</td>
#       <td id="T_f424c_row1_col4" class="data row1 col4" >0.0218</td>
#       <td id="T_f424c_row1_col5" class="data row1 col5" >0.3989</td>
#       <td id="T_f424c_row1_col6" class="data row1 col6" >0.9597</td>
#       <td id="T_f424c_row1_col7" class="data row1 col7" >1.8420</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_f424c_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_f424c_row2_col1" class="data row2 col1" >0.5028</td>
#       <td id="T_f424c_row2_col2" class="data row2 col2" >0.8702</td>
#       <td id="T_f424c_row2_col3" class="data row2 col3" >0.9325</td>
#       <td id="T_f424c_row2_col4" class="data row2 col4" >0.0218</td>
#       <td id="T_f424c_row2_col5" class="data row2 col5" >0.3989</td>
#       <td id="T_f424c_row2_col6" class="data row2 col6" >0.9597</td>
#       <td id="T_f424c_row2_col7" class="data row2 col7" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row3" class="row_heading level0 row3" >omp</th>
#       <td id="T_f424c_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f424c_row3_col1" class="data row3 col1" >0.5035</td>
#       <td id="T_f424c_row3_col2" class="data row3 col2" >0.8718</td>
#       <td id="T_f424c_row3_col3" class="data row3 col3" >0.9334</td>
#       <td id="T_f424c_row3_col4" class="data row3 col4" >0.0200</td>
#       <td id="T_f424c_row3_col5" class="data row3 col5" >0.3994</td>
#       <td id="T_f424c_row3_col6" class="data row3 col6" >0.9513</td>
#       <td id="T_f424c_row3_col7" class="data row3 col7" >0.1920</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_f424c_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_f424c_row4_col1" class="data row4 col1" >0.5048</td>
#       <td id="T_f424c_row4_col2" class="data row4 col2" >0.8747</td>
#       <td id="T_f424c_row4_col3" class="data row4 col3" >0.9350</td>
#       <td id="T_f424c_row4_col4" class="data row4 col4" >0.0167</td>
#       <td id="T_f424c_row4_col5" class="data row4 col5" >0.3994</td>
#       <td id="T_f424c_row4_col6" class="data row4 col6" >0.9117</td>
#       <td id="T_f424c_row4_col7" class="data row4 col7" >0.2540</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_f424c_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_f424c_row5_col1" class="data row5 col1" >0.5074</td>
#       <td id="T_f424c_row5_col2" class="data row5 col2" >0.8781</td>
#       <td id="T_f424c_row5_col3" class="data row5 col3" >0.9368</td>
#       <td id="T_f424c_row5_col4" class="data row5 col4" >0.0129</td>
#       <td id="T_f424c_row5_col5" class="data row5 col5" >0.4003</td>
#       <td id="T_f424c_row5_col6" class="data row5 col6" >0.8918</td>
#       <td id="T_f424c_row5_col7" class="data row5 col7" >0.7040</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row6" class="row_heading level0 row6" >llar</th>
#       <td id="T_f424c_row6_col0" class="data row6 col0" >Lasso Least Angle Regression</td>
#       <td id="T_f424c_row6_col1" class="data row6 col1" >0.5074</td>
#       <td id="T_f424c_row6_col2" class="data row6 col2" >0.8781</td>
#       <td id="T_f424c_row6_col3" class="data row6 col3" >0.9368</td>
#       <td id="T_f424c_row6_col4" class="data row6 col4" >0.0129</td>
#       <td id="T_f424c_row6_col5" class="data row6 col5" >0.4003</td>
#       <td id="T_f424c_row6_col6" class="data row6 col6" >0.8918</td>
#       <td id="T_f424c_row6_col7" class="data row6 col7" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_f424c_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_f424c_row7_col0" class="data row7 col0" >K Neighbors Regressor</td>
#       <td id="T_f424c_row7_col1" class="data row7 col1" >0.4885</td>
#       <td id="T_f424c_row7_col2" class="data row7 col2" >0.9310</td>
#       <td id="T_f424c_row7_col3" class="data row7 col3" >0.9647</td>
#       <td id="T_f424c_row7_col4" class="data row7 col4" >-0.0471</td>
#       <td id="T_f424c_row7_col5" class="data row7 col5" >0.4243</td>
#       <td id="T_f424c_row7_col6" class="data row7 col6" >1.4116</td>
#       <td id="T_f424c
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# KeyboardInterrupt

# %% [markdown]
# ## Percobaan 2: Drop feature gajelas

# %%
df_train = df_train.drop(['visibility','sea_level','grnd_level','rain_3h','snow_1h','snow_3h'],axis = 1)
df_test = df_test.drop(['visibility','sea_level','grnd_level','rain_3h','snow_1h','snow_3h'],axis = 1)

# %%
s2 = setup(df_train, target = 'rain_1h', session_id = 123)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 27
# <style type="text/css">
# #T_bee57_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bee57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bee57_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bee57_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bee57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bee57_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bee57_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bee57_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bee57_row1_col1" class="data row1 col1" >rain_1h</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bee57_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_bee57_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bee57_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_bee57_row3_col1" class="data row3 col1" >(341880, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bee57_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_bee57_row4_col1" class="data row4 col1" >(341880, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bee57_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_bee57_row5_col1" class="data row5 col1" >(239315, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bee57_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_bee57_row6_col1" class="data row6 col1" >(102565, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bee57_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_bee57_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bee57_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_bee57_row8_col1" class="data row8 col1" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bee57_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_bee57_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bee57_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_bee57_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bee57_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_bee57_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bee57_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_bee57_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bee57_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_bee57_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bee57_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_bee57_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bee57_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_bee57_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bee57_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_bee57_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bee57_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_bee57_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bee57_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_bee57_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bee57_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bee57_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_bee57_row19_col1" class="data row19 col1" >9819</td>
#     </tr>
#   </tbody>
# </table>

# %%
best2 = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 21:47:58
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# <style type="text/css">
# #T_78246 th {
#   text-align: left;
# }
# #T_78246_row0_col0, #T_78246_row0_col1, #T_78246_row0_col2, #T_78246_row0_col3, #T_78246_row0_col4, #T_78246_row0_col5, #T_78246_row0_col6, #T_78246_row0_col7, #T_78246_row1_col0, #T_78246_row1_col1, #T_78246_row1_col2, #T_78246_row1_col3, #T_78246_row1_col4, #T_78246_row1_col5, #T_78246_row1_col6, #T_78246_row1_col7, #T_78246_row2_col0, #T_78246_row2_col1, #T_78246_row2_col2, #T_78246_row2_col3, #T_78246_row2_col4, #T_78246_row2_col5, #T_78246_row2_col6, #T_78246_row2_col7, #T_78246_row3_col0, #T_78246_row3_col1, #T_78246_row3_col2, #T_78246_row3_col3, #T_78246_row3_col4, #T_78246_row3_col5, #T_78246_row3_col6, #T_78246_row3_col7, #T_78246_row4_col0, #T_78246_row4_col1, #T_78246_row4_col2, #T_78246_row4_col3, #T_78246_row4_col4, #T_78246_row4_col5, #T_78246_row4_col6, #T_78246_row4_col7, #T_78246_row5_col0, #T_78246_row5_col1, #T_78246_row5_col2, #T_78246_row5_col3, #T_78246_row5_col4, #T_78246_row5_col5, #T_78246_row5_col6, #T_78246_row5_col7, #T_78246_row6_col0, #T_78246_row6_col1, #T_78246_row6_col2, #T_78246_row6_col3, #T_78246_row6_col4, #T_78246_row6_col5, #T_78246_row6_col6, #T_78246_row6_col7, #T_78246_row7_col0, #T_78246_row7_col1, #T_78246_row7_col2, #T_78246_row7_col3, #T_78246_row7_col4, #T_78246_row7_col5, #T_78246_row7_col6, #T_78246_row7_col7, #T_78246_row8_col0, #T_78246_row8_col1, #T_78246_row8_col2, #T_78246_row8_col3, #T_78246_row8_col4, #T_78246_row8_col5, #T_78246_row8_col6, #T_78246_row8_col7, #T_78246_row9_col0, #T_78246_row9_col1, #T_78246_row9_col2, #T_78246_row9_col3, #T_78246_row9_col4, #T_78246_row9_col5, #T_78246_row9_col6, #T_78246_row9_col7, #T_78246_row10_col0, #T_78246_row10_col1, #T_78246_row10_col2, #T_78246_row10_col3, #T_78246_row10_col4, #T_78246_row10_col5, #T_78246_row10_col6, #T_78246_row10_col7, #T_78246_row11_col0, #T_78246_row11_col1, #T_78246_row11_col2, #T_78246_row11_col3, #T_78246_row11_col4, #T_78246_row11_col5, #T_78246_row11_col6, #T_78246_row11_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_78246">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78246_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_78246_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_78246_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_78246_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_78246_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_78246_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_78246_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_78246_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78246_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_78246_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_78246_row0_col1" class="data row0 col1" >0.5027</td>
#       <td id="T_78246_row0_col2" class="data row0 col2" >0.8701</td>
#       <td id="T_78246_row0_col3" class="data row0 col3" >0.9325</td>
#       <td id="T_78246_row0_col4" class="data row0 col4" >0.0219</td>
#       <td id="T_78246_row0_col5" class="data row0 col5" >0.3988</td>
#       <td id="T_78246_row0_col6" class="data row0 col6" >0.9592</td>
#       <td id="T_78246_row0_col7" class="data row0 col7" >0.2880</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_78246_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_78246_row1_col1" class="data row1 col1" >0.5027</td>
#       <td id="T_78246_row1_col2" class="data row1 col2" >0.8701</td>
#       <td id="T_78246_row1_col3" class="data row1 col3" >0.9325</td>
#       <td id="T_78246_row1_col4" class="data row1 col4" >0.0219</td>
#       <td id="T_78246_row1_col5" class="data row1 col5" >0.3988</td>
#       <td id="T_78246_row1_col6" class="data row1 col6" >0.9592</td>
#       <td id="T_78246_row1_col7" class="data row1 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_78246_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_78246_row2_col1" class="data row2 col1" >0.5027</td>
#       <td id="T_78246_row2_col2" class="data row2 col2" >0.8701</td>
#       <td id="T_78246_row2_col3" class="data row2 col3" >0.9325</td>
#       <td id="T_78246_row2_col4" class="data row2 col4" >0.0219</td>
#       <td id="T_78246_row2_col5" class="data row2 col5" >0.3988</td>
#       <td id="T_78246_row2_col6" class="data row2 col6" >0.9592</td>
#       <td id="T_78246_row2_col7" class="data row2 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_78246_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_78246_row3_col1" class="data row3 col1" >0.5027</td>
#       <td id="T_78246_row3_col2" class="data row3 col2" >0.8701</td>
#       <td id="T_78246_row3_col3" class="data row3 col3" >0.9325</td>
#       <td id="T_78246_row3_col4" class="data row3 col4" >0.0219</td>
#       <td id="T_78246_row3_col5" class="data row3 col5" >0.3988</td>
#       <td id="T_78246_row3_col6" class="data row3 col6" >0.9588</td>
#       <td id="T_78246_row3_col7" class="data row3 col7" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_78246_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_78246_row4_col1" class="data row4 col1" >0.5048</td>
#       <td id="T_78246_row4_col2" class="data row4 col2" >0.8747</td>
#       <td id="T_78246_row4_col3" class="data row4 col3" >0.9350</td>
#       <td id="T_78246_row4_col4" class="data row4 col4" >0.0167</td>
#       <td id="T_78246_row4_col5" class="data row4 col5" >0.3994</td>
#       <td id="T_78246_row4_col6" class="data row4 col6" >0.9117</td>
#       <td id="T_78246_row4_col7" class="data row4 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_78246_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_78246_row5_col1" class="data row5 col1" >0.5074</td>
#       <td id="T_78246_row5_col2" class="data row5 col2" >0.8781</td>
#       <td id="T_78246_row5_col3" class="data row5 col3" >0.9368</td>
#       <td id="T_78246_row5_col4" class="data row5 col4" >0.0129</td>
#       <td id="T_78246_row5_col5" class="data row5 col5" >0.4003</td>
#       <td id="T_78246_row5_col6" class="data row5 col6" >0.8918</td>
#       <td id="T_78246_row5_col7" class="data row5 col7" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row6" class="row_heading level0 row6" >llar</th>
#       <td id="T_78246_row6_col0" class="data row6 col0" >Lasso Least Angle Regression</td>
#       <td id="T_78246_row6_col1" class="data row6 col1" >0.5074</td>
#       <td id="T_78246_row6_col2" class="data row6 col2" >0.8781</td>
#       <td id="T_78246_row6_col3" class="data row6 col3" >0.9368</td>
#       <td id="T_78246_row6_col4" class="data row6 col4" >0.0129</td>
#       <td id="T_78246_row6_col5" class="data row6 col5" >0.4003</td>
#       <td id="T_78246_row6_col6" class="data row6 col6" >0.8918</td>
#       <td id="T_78246_row6_col7" class="data row6 col7" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_78246_level0_row7" class="row_heading level0 row7" >omp</th>
#       <td id="T_78246_row7_col0" class="data row7 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_78246_row7_col1" class="data row7 col1" >0.5153</td>
#       <td id="T_78246_row7_col2" class="data row7 col2" >0.8892</td>
#       <td id="T_78246_row7_col3" class="data row7 col3" >0.9427</td>
#       <td id="T_78246_row7_col4" class="data row7 col4" >0.0003</td>
#       <td id="T_78246_row7_col5" class="data row7 col5" >0.4052</td>
#       <td id="T_78246_row7_col6" class="data row7 col6" >0.8712</td>
#       <td id="T_78246
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
# KeyboardInterrupt
